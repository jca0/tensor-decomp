# %%
import numpy as np
from tensor_decomp_algs import *
from data_gen import *
from utils import *
from experiments import *

# %%
experiment1()
# Out:
# ...
# 100%|██████████| 10/10 [05:46<00:00, 34.70s/it]
